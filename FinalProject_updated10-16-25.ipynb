# %% [markdown]
# ## Loading Necessary Libraries

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
from scipy.stats import norm 
import math
from matplotlib import gridspec
from scipy.stats import chi2_contingency
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %% [markdown]
# ## Reading in the Datasheet and Looking over the Data

# %%
# reading in the stroke file & seeing first few rows of data
stroke = pd.read_csv('healthcare-dataset-stroke-data.csv')
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# adding clearer headers
stroke.columns = ['ID', 'Gender', 'Age', 'Hypertension', 'Heart Disease', 'Ever Married', 'Work Type', 'Residence Type', 'AVG Glucose Level', 'BMI', 'Smoking Status', 'Stroke']

# %%
# obtain descriptive statistics for the columns
stroke.describe()
# Out:
#                  ID          Age  Hypertension  Heart Disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        AVG Glucose Level          BMI       Stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %% [markdown]
# ## Processing the Data

# %% [markdown]
# ### Finding Missing Values

# %%
# count of the missing values per column
stroke.isnull().sum()
# Out:
# ID                     0
# Gender                 0
# Age                    0
# Hypertension           0
# Heart Disease          0
# Ever Married           0
# Work Type              0
# Residence Type         0
# AVG Glucose Level      0
# BMI                  201
# Smoking Status         0
# Stroke                 0
# dtype: int64

# %% [markdown]
# ### Filling in Missing Values

# %%
# filling missing data in BMI column with "not provided"
stroke.fillna("not provided")
# Out:
#          ID  Gender   Age  Hypertension  Heart Disease Ever Married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           Work Type Residence Type  AVG Glucose Level           BMI  \
# 0           Private          Urban             228.69          36.6
# ...

# %% [markdown]
# ### Examining the Data Visually with Bar Plots and Histograms

# %%
# Visualize distribution of each variable --> referencing module 5 lab
fig1, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 5))
fig2, (ax4, ax5, ax6) = plt.subplots(1, 3, figsize=(12, 5))
fig3, (ax7, ax8) = plt.subplots(1, 2, figsize=(12, 5))
fig4, (ax9, ax10, ax11) = plt.subplots(1, 3, figsize=(12, 5))

# setting up bar plots for data that has discrete values
# for data labels, had to google how to add data labels when using value_counts

# Gender
gender = stroke['Gender'].value_counts().plot(ax=ax1, kind='bar', xlabel='Gender', ylabel='Frequency', title='Survey Responses - Gender', rot=45)
# data labels
for g in gender.containers:
    gender.bar_label(g, fmt='%d')

# Hypertension
hypertension = stroke['Hypertension'].value_counts().plot(ax=ax2, kind='bar', xlabel='Hypertension', ylabel='Frequency', title='Survey Responses - Hypertension', rot=45)
# data labels
for h in hypertension.containers:
    hypertension.bar_label(h, fmt='%d')

# Heart Disease
heart_disease = stroke['Heart Disease'].value_counts().plot(ax=ax3, kind='bar', xlabel='Heart Disease', ylabel='Frequency', title='Survey Responses - Heart Disease', rot=45)
# data labels
for hd in heart_disease.containers:
    heart_disease.bar_label(hd, fmt='%d')

# Ever Married
married = stroke['Ever Married'].value_counts().plot(ax=ax4, kind='bar', xlabel='Ever Married', ylabel='Frequency', title='Survey Responses - Ever Married', rot=45)
# data labels
for m in married.containers:
    married.bar_label(m, fmt='%d')

# Work Type
work = stroke['Work Type'].value_counts().plot(ax=ax5, kind='bar', xlabel='Work Type', ylabel='Frequency', title='Survey Responses - Work Type', rot=45)
# data labels
for w in work.containers:
    work.bar_label(w, fmt='%d')

# Residence Type
residence = stroke['Residence Type'].value_counts().plot(ax=ax6, kind='bar', xlabel='Residence Type', ylabel='Frequency', title='Survey Responses - Residence Type', rot=45)
# data labels
for r in residence.containers:
    residence.bar_label(r, fmt='%d')

# Smoking Status
smoke = stroke['Smoking Status'].value_counts().plot(ax=ax7, kind='bar', xlabel='Smoking Status', ylabel='Frequency', title='Survey Responses - Smoking Status', rot=45)
# data labels
for sm in smoke.containers:
    smoke.bar_label(sm, fmt='%d')

# Stroke
stroke_occurrence = stroke['Stroke'].value_counts().plot(ax=ax8, kind='bar', xlabel='Stroke', ylabel='Frequency', title='Survey Responses - Stroke', rot=45)
# data labels
for so in stroke_occurrence.containers:
    stroke_occurrence.bar_label(so, fmt='%d')

# Age
stroke['Age'].plot(ax=ax9, kind='hist', xlabel='Age', ylabel='Frequency', title='Survey Responses - Age', color='lightblue', edgecolor='black', rot=45)
# Average Glucose Levels
stroke['AVG Glucose Level'].plot(ax=ax10, kind='hist', xlabel='Average Glucose Level', ylabel='Frequency', title='Survey Responses - Average Glucose Level', color='lightblue', edgecolor='black', rot=45)
# BMI
stroke['BMI'].plot(ax=ax11, kind='hist', xlabel='BMI', ylabel='Frequency', title='Survey Responses - BMI', color='lightblue', edgecolor='black', rot=45)


fig1.tight_layout()
fig2.tight_layout()
fig3.tight_layout()
fig4.tight_layout()


plt.show()

# %% [markdown]
# ### Examining the relationship between Discrete Variables and Having a Stroke

# %%
# using code from module 5 lab to create the stacked bar plot data
# googled "how to add data labels to python stacked bar chart" for help creating code using container and bar label

# Visualize relationship between stroke and various variables
# defining the plots
fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6], [ax7, ax8]] = plt.subplots(4, 2, figsize=(20, 34))
plt.rc('font', size=14)  # Adjust 14 to your desired size

#defining color scheme so labeling is legable
colors = ['lightblue', 'bisque', 'thistle']
plt.rc('axes', titlesize=16)

# Count for gender and stroke
gen_stack = stroke.groupby(['Stroke', 'Gender']).size().unstack().plot(ax=ax1, kind='bar', stacked=True, xlabel='Stroke Occurrence by Gender', 
                                                                ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Gender (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and gender
for g_stacked in gen_stack.containers:
    gen_stack.bar_label(g_stacked, label_type='center')

# Count for stroke and hypertension
hyp_stack = stroke.groupby(['Stroke', 'Hypertension']).size().unstack().plot(ax=ax2, kind='bar', stacked=True, xlabel='Stoke Occurrence by Presence of Hypertension', 
                                                                  ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Hypertension (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and hypertension
for h_stacked in hyp_stack.containers:
    hyp_stack.bar_label(h_stacked, label_type='center')

# Count for heart disease and stroke
hd_stack = stroke.groupby(['Stroke', 'Heart Disease']).size().unstack().plot(ax=ax3, kind='bar', stacked=True, xlabel='Stroke Occurrence by Presence of Heart Disease', 
                                                                ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Heart Disease (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and heart disease
for hd_stacked in hd_stack.containers:
    hd_stack.bar_label(hd_stacked, label_type='center')

# Count for marriage and stroke
m_stack = stroke.groupby(['Stroke', 'Ever Married']).size().unstack().plot(ax=ax4, kind='bar', stacked=True, xlabel='Stroke Occurrence by Marriage Status', 
                                                                ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Marriage (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and marriage
for m_stacked in m_stack.containers:
    m_stack.bar_label(m_stacked, label_type='center')

# Count for work type and stroke
w_stack = stroke.groupby(['Work Type', 'Stroke']).size().unstack().plot(ax=ax5, kind='bar', stacked=True, xlabel='Work Type Impact on Stroke Occurrence',
                                                                ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Work Type (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and work
for w_stacked in w_stack.containers:
    w_stack.bar_label(w_stacked, label_type='center')

# Count for residence type and stroke
r_stack = stroke.groupby(['Stroke', 'Residence Type']).size().unstack().plot(ax=ax6, kind='bar', stacked=True, xlabel='Stroke Occurrence by Residence Type', 
                                                                ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Residence Type (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and residence
for r_stacked in r_stack.containers:
    r_stack.bar_label(r_stacked, label_type='center')

# Count for smoking status and stroke
smoke_stack = stroke.groupby(['Smoking Status', 'Stroke']).size().unstack().plot(ax=ax7, kind='bar', stacked=True, xlabel='Smoking Status Impact on Stroke Occurrence', 
                                                                ylabel='Frequency', title='Survey Responses - Stroke Occurrence by Smoking Status (Count)', rot=45, color=colors)
# adding labels for the relationship between stroke and smoking
for smoke_stacked in smoke_stack.containers:
    smoke_stack.bar_label(smoke_stacked, label_type='center')

fig.delaxes(ax8)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Creating Frequency Tables for Discrete Variables

# %%
# Create frequency tables - hypertension
bold = '\033[1m'
normal = '\033[0m'

print(f'{bold}Frequncy Table - Hypertension{normal}')
hypertension_table = pd.crosstab(stroke['Hypertension'], stroke['Stroke'])
print(hypertension_table)
print(' ')
print(pd.crosstab(stroke['Hypertension'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - gender
print(f'{bold}Frequncy Table - Gender{normal}')
gender_table = pd.crosstab(stroke['Gender'], stroke['Stroke'])
print(gender_table)
print(' ')
print(pd.crosstab(stroke['Gender'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - heart disease
print(f'{bold}Frequncy Table - Heart Disease{normal}')
hd_table = pd.crosstab(stroke['Heart Disease'], stroke['Stroke'])
print(hd_table)
print(' ')
print(pd.crosstab(stroke['Heart Disease'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - ever married
print(f'{bold}Frequncy Table - Ever Married{normal}')
em_table = pd.crosstab(stroke['Ever Married'], stroke['Stroke'])
print(em_table)
print(' ')
print(pd.crosstab(stroke['Ever Married'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - work type
print(f'{bold}Frequncy Table - Work Type{normal}')
wt_table = pd.crosstab(stroke['Work Type'], stroke['Stroke'])
print(wt_table)
print(' ')
print(pd.crosstab(stroke['Work Type'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - residence type
print(f'{bold}Frequncy Table - Residence Type{normal}')
rt_table = pd.crosstab(stroke['Residence Type'], stroke['Stroke'])
print(rt_table)
print(' ')
print(pd.crosstab(stroke['Residence Type'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - smoking status
print(f'{bold}Frequncy Table - Smoking Status{normal}')
ss_table = pd.crosstab(stroke['Smoking Status'], stroke['Stroke'])
print(ss_table)
print(' ')
print(pd.crosstab(stroke['Smoking Status'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - age
print(f'{bold}Frequncy Table - Age{normal}')
age_table = pd.crosstab(stroke['Age'], stroke['Stroke'])
print(age_table)
print(' ')
print(pd.crosstab(stroke['Age'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - glucose
print(f'{bold}Frequncy Table - Glucose{normal}')
gl_table = pd.crosstab(stroke['AVG Glucose Level'], stroke['Stroke'])
print(gl_table)
print(' ')
print(pd.crosstab(stroke['AVG Glucose Level'], stroke['Stroke'], normalize='index'))
print('\n')

# Create frequency tables - BMI
print(f'{bold}Frequncy Table - BMI{normal}')
bmi_table = pd.crosstab(stroke['BMI'], stroke['Stroke'])
print(gl_table)
print(' ')
print(pd.crosstab(stroke['BMI'], stroke['Stroke'], normalize='index'))
print('\n')
# Out:
# Frequncy Table - Hypertension
# Stroke           0    1
# Hypertension
# 0             4429  183
# 1              432   66
#
# Stroke               0         1
# Hypertension
# 0             0.960321  0.039679
# 1             0.867470  0.132530
#
#
# Frequncy Table - Gender
# Stroke     0    1
# Gender
# Female  2853  141
# Male    2007  108
# Other      1    0
#
# Stroke         0         1
# Gender
# Female  0.952906  0.047094
# Male    0.948936  0.051064
# Other   1.000000  0.000000
#
#
# Frequncy Table - Heart Disease
# Stroke            0    1
# Heart Disease
# 0              4632  202
# 1               229   47
#
# Stroke                0         1
# Heart Disease
# 0              0.958213  0.041787
# 1              0.829710  0.170290
#
#
# Frequncy Table - Ever Married
# Stroke           0    1
# Ever Married
# No            1728   29
# Yes           3133  220
#
# Stroke               0         1
# Ever Married
# No            0.983495  0.016505
# ...

# %% [markdown]
# ### Examining Chi Test results to determine relationship between Stroke and Dependent Variable

# %%
# Using from Module 5 Lab - Creating function for ch-square test to determine relationships
def chisquare_test(table):
    stat, p_value, dof, expected = chi2_contingency(table, correction=False)
    # Interpret p-value
    alpha = 0.05
    print("The p-value is {}".format(p_value))
    if p_value <= alpha:
        print('Relationship between variables')
    else:
        print('NO relationship between variables.')

# %%
# Perform chi-square test to determine if there is a relationship between stroke and hypertension
print(f'{bold}Chi-Square Test - Hypertension{normal}')
chisquare_test(hypertension_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and gender
print(f'{bold}Chi-Square Test - Gender{normal}')
chisquare_test(gender_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and heart disease
print(f'{bold}Chi-Square Test - Heart Disease{normal}')
chisquare_test(hd_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and ever married
print(f'{bold}Chi-Square Test - Ever Married{normal}')
chisquare_test(em_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and work type
print(f'{bold}Chi-Square Test - Work Type{normal}')
chisquare_test(wt_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and work type
print(f'{bold}Chi-Square Test - Residence Type{normal}')
chisquare_test(rt_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and smoking status
print(f'{bold}Chi-Square Test - Smoking Status{normal}')
chisquare_test(ss_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and age
print(f'{bold}Chi-Square Test - Age{normal}')
chisquare_test(age_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and glucose
print(f'{bold}Chi-Square Test - Glucose{normal}')
chisquare_test(gl_table)
print('\n')

# Perform chi-square test to determine if there is a relationship between stroke and BMI
print(f'{bold}Chi-Square Test - BMI{normal}')
chisquare_test(bmi_table)
print('\n')
# Out:
# Chi-Square Test - Hypertension
# The p-value is 6.068123323489793e-20
# Relationship between variables
#
#
# Chi-Square Test - Gender
# The p-value is 0.7895490538408245
# NO relationship between variables.
#
#
# Chi-Square Test - Heart Disease
# The p-value is 5.200109767379846e-22
# Relationship between variables
#
#
# Chi-Square Test - Ever Married
# The p-value is 9.58932501427625e-15
# Relationship between variables
#
#
# Chi-Square Test - Work Type
# The p-value is 5.397707801896119e-10
# Relationship between variables
#
#
# Chi-Square Test - Residence Type
# The p-value is 0.26915903227493193
# NO relationship between variables.
#
#
# Chi-Square Test - Smoking Status
# The p-value is 2.0853997025008455e-06
# Relationship between variables
#
#
# Chi-Square Test - Age
# The p-value is 5.161745862440517e-52
# Relationship between variables
#
#
# Chi-Square Test - Glucose
# The p-value is 0.016045842421853904
# Relationship between variables
#
#
# Chi-Square Test - BMI
# ...

# %% [markdown]
# ## Detailed Examination between Variables that Show Relationship to Stroke

# %% [markdown]
# ### Creating a New Data Frame

# %%
# removing the columns that are no longer needed
stroke_corr = stroke.drop(['ID','Gender', 'Residence Type', 'BMI'], axis=1)

# converting string data into numerical format for processing  --> googled how to convert strings into numbers in a dataframe for assistance
le = LabelEncoder()
stroke_corr['Ever Married'] = le.fit_transform(stroke_corr['Ever Married'])
stroke_corr['Work Type'] = le.fit_transform(stroke_corr['Work Type'])
stroke_corr['Smoking Status'] = le.fit_transform(stroke_corr['Smoking Status'])

correlation_matrix = stroke_corr.corr()
#print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >
